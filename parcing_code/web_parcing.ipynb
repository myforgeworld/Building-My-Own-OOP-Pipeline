# %% [markdown]
# # WEB-parcing

# %% [markdown]
# Так как самые первые данные я выгружал из *Kaggle*, я решил что надо написать **web-parcer** для загрузки таких же данных такими же атрибутами с сайта **Airbnb**. Это будет считаться как хорошей практикой! В этом блоке я напишу парсер, настрою **airflow** а также построю свою базу данных.

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
BASE_URL = 'https://www.airbnb.ru'
# DRIVER_PATH = "geckodriver\geckodriver.exe"

# %%
driver = webdriver.Firefox()
driver.get(BASE_URL)

wait = WebDriverWait(driver, 20)

time.sleep(5)

driver.quit()
